# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![](https://scontent.ftpe8-2.fna.fbcdn.net/v/t39.30808-6/489469722_24269845685937561_626421733008515430_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=127cfc&_nc_ohc=Fkoluzq__Q8Q7kNvwFfE2Vy&_nc_oc=Adk9WACWz5UM3EG5cOzZmC3G_yjzsdDjD6QY3VsTbFrtrxZLaBtd2DlGmF9kYQXGe0jkJ3RxgNqdIhRb5iQ2b_2F&_nc_zt=23&_nc_ht=scontent.ftpe8-2.fna&_nc_gid=ZuCCB0fFlAB1JUcM9844Jw&oh=00_AfEfdEHtabNLsGZhYn6cTayovsE0oE0BIqMiAgfFbu5onQ&oe=67F80DC5)

# %%
def dfs(graph, start, goal, path=None, visited=None):
    if path is None:
        path = []
    if visited is None:
        visited = set()

    path.append(start)
    visited.add(start)

    if start == goal:
        return path  # 找到目標，回傳目前的路徑

    for neighbor in graph.get(start, []):
        if neighbor not in visited:
            result = dfs(graph, neighbor, goal, path.copy(), visited.copy())
            if result is not None:
                return result  # 如果有找到就回傳

    return None  # 沒有找到

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# %%
graph.get('A', [])
# Out:
# ['B', 'C']

# %% [markdown]
# ![](https://scontent.ftpe8-2.fna.fbcdn.net/v/t39.30808-6/489629254_24269852359270227_3386491712421602630_n.jpg?_nc_cat=102&ccb=1-7&_nc_sid=127cfc&_nc_ohc=K0Sor-I0JpUQ7kNvwH6Awg2&_nc_oc=Adn_VbxZTOefjuB9r51bd1IzvuPbIx-nbda4Mw0nsYdQRchWmIkIHAhBmKEoc2_z-mEZ3X7nl5-sVApPjrjZfbpV&_nc_zt=23&_nc_ht=scontent.ftpe8-2.fna&_nc_gid=MK4ISUgfpov4-T_hc5MKZQ&oh=00_AfEXp5g4Zel9HKWA_HKGTZCA3GvMv1cC9R5DZYdOGr0L7A&oe=67F81526)

# %%
# 執行 DFS，從 A 找到 F 的路徑
path = dfs(graph, 'A', 'F')
print("Path from A to F:", path)
# Out:
# Path from A to F: ['A', 'B', 'D', 'F']

# %% [markdown]
# ![](https://scontent.ftpe8-2.fna.fbcdn.net/v/t39.30808-6/489434165_24269915852597211_2514188489233621893_n.jpg?_nc_cat=100&ccb=1-7&_nc_sid=127cfc&_nc_ohc=YYnPnbBbSXUQ7kNvwFf5kyQ&_nc_oc=Adlo5sHsphG9peCuE4V0w1lQ0eL6CENwvMH5jBLm3MibyStUNkaDudGReUNWMJA4xMcsdYN4Z8fj7al2a1UQLA8e&_nc_zt=23&_nc_ht=scontent.ftpe8-2.fna&_nc_gid=pXT1CjtzLiYW0BXHKCUPkA&oh=00_AfHgj4v48ofLzT2nDpJPtTk1c6jJ7ow-TUS9h6bLIyvW1g&oe=67F844D4)

# %%
from collections import deque

def bfs_with_path(graph, start, goal):
    visited = set()
    queue = deque([[start]])
    
    while queue:
        print(queue)
        path = queue.popleft()
        node = path[-1]

        if node == goal:
            return path

        if node not in visited:
            visited.add(node)
            for neighbor in graph.get(node, []):
                new_path = path + [neighbor]
                queue.append(new_path)

    return None

# %%
queue = deque([['A']])

# %%
queue
# Out:
# deque([['A']])

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': ['G'],
    'E': ['H'],
    'F': ['I'],
    'G': ['J'],
    'H': ['J'],
    'I': ['K'],
    'J': [],
    'K': []
}

# %% [markdown]
# ![](https://scontent.ftpe8-2.fna.fbcdn.net/v/t39.30808-6/488525242_24269946102594186_4533984863245452952_n.jpg?_nc_cat=107&ccb=1-7&_nc_sid=127cfc&_nc_ohc=_ItKluPAwo0Q7kNvwGmwvRQ&_nc_oc=AdlAgLJhAwjDdk_lKkuMV0yJqgouVBof3N1RDhN7GUDjUHbgtulx-e0tTVQWawPMfGmfyMyilhLerjluD_6RNWbB&_nc_zt=23&_nc_ht=scontent.ftpe8-2.fna&_nc_gid=1Kh6PVDX498hmSa1j5HVbA&oh=00_AfGnbeaII6n6q8c8mOQvqOqjTk-W4RZTMP1cfMYoPL70ew&oe=67F83480)

# %%
start = 'A'
goal = 'J'

path = bfs_with_path(graph, start, goal)
print("from", start, "to", goal, "shortest_path:", path)
# Out:
# deque([['A']])
# deque([['A', 'B'], ['A', 'C']])
# deque([['A', 'C'], ['A', 'B', 'D'], ['A', 'B', 'E']])
# deque([['A', 'B', 'D'], ['A', 'B', 'E'], ['A', 'C', 'F']])
# deque([['A', 'B', 'E'], ['A', 'C', 'F'], ['A', 'B', 'D', 'G']])
# deque([['A', 'C', 'F'], ['A', 'B', 'D', 'G'], ['A', 'B', 'E', 'H']])
# deque([['A', 'B', 'D', 'G'], ['A', 'B', 'E', 'H'], ['A', 'C', 'F', 'I']])
# deque([['A', 'B', 'E', 'H'], ['A', 'C', 'F', 'I'], ['A', 'B', 'D', 'G', 'J']])
# deque([['A', 'C', 'F', 'I'], ['A', 'B', 'D', 'G', 'J'], ['A', 'B', 'E', 'H', 'J']])
# deque([['A', 'B', 'D', 'G', 'J'], ['A', 'B', 'E', 'H', 'J'], ['A', 'C', 'F', 'I', 'K']])
# from A to J shortest_path: ['A', 'B', 'D', 'G', 'J']
